# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from tqdm import tqdm
from sklearn.linear_model import LinearRegression
from xgboost import XGBClassifier

# %%
df_train=pd.read_csv("train.csv",parse_dates=['date'], index_col='date')
df_test=pd.read_csv("test.csv",parse_dates=['date'], index_col='date')
df_train['month']=df_train.index.month
df_train['day']=df_train.index.day
df_test['month']=df_test.index.month
df_test['day']=df_test.index.day

# %%
df_train.head(5)
# Out:
#             warehouse_id  product_id  quantity  id  month  day
# date
# 2020-12-02             0       71165         1   0     12    2
# 2020-12-03             0       71165         3   1     12    3
# 2020-12-07             0       71165         2   2     12    7
# 2020-12-08             0       71165         2   3     12    8
# 2020-12-09             0       71165         3   4     12    9

# %%
set1=set(df_train['product_id'])
set2=set(df_test['product_id'])
print(len(set1))
print(len(set1.intersection(set2)))
# Out:
# 3288
# 3288

# %%
train=df_train[df_train['month']!=4].copy()
train.shape
# Out:
# (72196, 6)

# %%
val=df_train[df_train['month']==4].copy()
val.shape
# Out:
# (5871, 6)

# %%
train['label'] = 'train'
val['label'] = 'val'

df = pd.concat((train,val), axis = 0)
df['target'] = np.where(df.label == 'train', df.quantity, np.nan)
df.head(2)
# Out:
#             warehouse_id  product_id  quantity  id  month  day  label  target
# date
# 2020-12-02             0       71165         1   0     12    2  train     1.0
# 2020-12-03             0       71165         3   1     12    3  train     3.0

# %%
def add_lags(tek_df):
    lag_period = 7
    features = []
    for period_mult in range(1,4,1):
        tek_df["lag_period_{}".format(period_mult)] = tek_df.quantity.shift(period_mult*lag_period)
        features.append("lag_period_{}".format(period_mult))

    tek_df['lagf_mean'] = tek_df[features].mean(axis = 1)
    tek_df['lagf_std'] = tek_df[features].std(axis = 1)
    features.extend(['lagf_mean'])
    features.extend(['lagf_std'])
    return tek_df,features

# %%
tek_df=df[df['product_id']==71165]
tek_df=tek_df[tek_df['warehouse_id']==0]
tek_df.label.unique()
# Out:
# array(['train', 'val'], dtype=object)

# %%
tek_df[tek_df['label']=='val']
# Out:
#             warehouse_id  product_id  quantity  id  month  day label  target
# date
# 2021-04-02             0       71165         2  91      4    2   val     NaN
# 2021-04-03             0       71165         7  92      4    3   val     NaN
# 2021-04-04             0       71165         4  93      4    4   val     NaN
# 2021-04-05             0       71165         2  94      4    5   val     NaN
# 2021-04-06             0       71165         6  95      4    6   val     NaN
# 2021-04-07             0       71165         2  96      4    7   val     NaN

# %%
tek_df,features=add_lags(tek_df)

# %%
model = LinearRegression()
tek_train_df = tek_df[tek_df.label == 'train'][features + ['target']].dropna()
tek_test_df = tek_df[tek_df.label == 'val'][features]

model.fit(tek_train_df.drop('target', axis = 1) ,tek_train_df['target'])
forecast = model.predict(tek_test_df)
tek_test_df['prediction'] = forecast

# %%
tek_test_df
# Out:
#             lag_period_1  lag_period_2  lag_period_3  lagf_mean  lagf_std  \
# date
# 2021-04-02           1.0          16.0           3.0   6.666667  8.144528
# 2021-04-03           4.0           6.0           5.0   5.000000  1.000000
# 2021-04-04           2.0           1.0           1.0   1.333333  0.577350
# 2021-04-05           4.0           2.0           2.0   2.666667  1.154701
# 2021-04-06           3.0           2.0           3.0   2.666667  0.577350
# 2021-04-07           3.0           2.0           1.0   2.000000  1.000000
#
#             prediction
# date
# 2021-04-02    2.973396
# 2021-04-03    3.014053
# 2021-04-04    3.874104
# 2021-04-05    4.157729
# 2021-04-06    3.602580
# 2021-04-07    4.069994

# %%
tek_df[tek_df['label']=='val']
# Out:
#             warehouse_id  product_id  quantity  id  month  day label  target  \
# date
# 2021-04-02             0       71165         2  91      4    2   val     NaN
# 2021-04-03             0       71165         7  92      4    3   val     NaN
# 2021-04-04             0       71165         4  93      4    4   val     NaN
# 2021-04-05             0       71165         2  94      4    5   val     NaN
# 2021-04-06             0       71165         6  95      4    6   val     NaN
# 2021-04-07             0       71165         2  96      4    7   val     NaN
#
#             lag_period_1  lag_period_2  lag_period_3  lagf_mean  lagf_std
# date
# 2021-04-02           1.0          16.0           3.0   6.666667  8.144528
# 2021-04-03           4.0           6.0           5.0   5.000000  1.000000
# 2021-04-04           2.0           1.0           1.0   1.333333  0.577350
# 2021-04-05           4.0           2.0           2.0   2.666667  1.154701
# 2021-04-06           3.0           2.0           3.0   2.666667  0.577350
# 2021-04-07           3.0           2.0           1.0   2.000000  1.000000

# %%
plt.figure(figsize=(16,8))
plt.plot(tek_df[tek_df['label']=='val'].quantity, label='Train')
plt.plot(tek_test_df.prediction, label='linear')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(tek_df[tek_df['label']=='val'].quantity,tek_test_df.prediction))
# Out:
# 5.256569432320864

# %%
Это слишком много, но все же попробуем залить это в кэггл

# %%
df_test.shape
# Out:
# (46032, 6)

# %%
df_train['label'] = 'train'
df_test['label'] = 'test'

df = pd.concat((df_train,df_test), axis = 0,sort=True)
df['target'] = np.where(df.label == 'train', df.quantity, np.nan)
df.head(2)
# Out:
#             day  id  label  month  product_id  quantity  warehouse_id  target
# date
# 2020-12-02    2   0  train     12       71165       1.0             0     1.0
# 2020-12-03    3   1  train     12       71165       3.0             0     3.0

# %%
otv_df=pd.DataFrame(columns=['id'])
otv_df.head(5)
# Out:
# Empty DataFrame
# Columns: [id]
# Index: []

# %%
for tek_prod_id in tqdm(df_test['product_id'].unique()[1:2]):
    for tek_store_id in [0,1]:
        tek_df=df[df['product_id']==tek_prod_id]
        tek_df=tek_df[tek_df['warehouse_id']==tek_store_id]
        
        tek_df,features=add_lags(tek_df)
        
        model = LinearRegression()
        tek_train_df = tek_df[tek_df.label == 'train'][features + ['target']].dropna()
        tek_test_df = tek_df[tek_df.label == 'test'][features]
        
        print(tek_prod_id, tek_store_id,len(tek_train_df),len(tek_test_df))

        model.fit(tek_train_df.drop('target', axis = 1) ,tek_train_df['target'])
        forecast = model.predict(tek_test_df)
        
        newt=tek_df[tek_df.label == 'test'].copy()[['id']]
        newt['prediction'] = forecast
        otv_df = pd.concat((otv_df,newt), axis = 0,sort=True)
        
    

otv_df.shape
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 71170 0 0 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-357-beece3d2937e> in <module>
#      12         print(tek_prod_id, tek_store_id,len(tek_train_df),len(tek_test_df))
#      13
# ---> 14         model.fit(tek_train_df.drop('target', axis = 1) ,tek_train_df['target'])
#      15         forecast = model.predict(tek_test_df)
#      16
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     548                              " minimum of %d is required%s."
#     549                              % (n_samples, array.shape, ensure_min_samples,
# --> 550                                 context))
#     551
#     552     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 5)) while a minimum of 1 is required.

# %%
tek_df=df[df['product_id']==71170]
tek_df=tek_df[tek_df['warehouse_id']==0]
        
tek_df,features=add_lags(tek_df)
        
# model = LinearRegression()
# tek_train_df = tek_df[tek_df.label == 'train'][features + ['target']].dropna()
# tek_test_df = tek_df[tek_df.label == 'test'][features]
        
    
tek_df
# Out:
#             day     id  label  month  product_id  quantity  warehouse_id  \
# date
# 2021-02-09    9    104  train      2       71170       1.0             0
# 2021-02-10   10    105  train      2       71170       3.0             0
# 2021-02-11   11    106  train      2       71170       3.0             0
# 2021-02-12   12    107  train      2       71170       3.0             0
# 2021-02-14   14    108  train      2       71170       2.0             0
# 2021-02-15   15    109  train      2       71170       1.0             0
# 2021-02-16   16    110  train      2       71170       3.0             0
# 2021-02-17   17    111  train      2       71170       2.0             0
# 2021-02-18   18    112  train      2       71170       4.0             0
# 2021-02-20   20    113  train      2       71170       2.0             0
# 2021-02-23   23    114  train      2       71170       1.0             0
# 2021-02-26   26    115  train      2       71170       1.0             0
# 2021-02-27   27    116  train      2       71170       2.0             0
# 2021-02-28   28    117  train      2       71170       3.0             0
# 2021-03-01    1    118  train      3       71170       2.0             0
# 2021-03-02    2    119  train      3       71170       1.0             0
# 2021-03-03    3    120  train      3       71170       2.0             0
# 2021-03-04    4    121  train      3       71170       3.0             0
# 2021-03-06    6    122  train      3       71170       7.0             0
# 2021-03-07    7    123  train      3       71170       4.0             0
# 2021-03-08    8    124  train      3       71170       3.0             0
# 2021-03-23   23    125  train      3       71170       3.0             0
# 2021-03-24   24    126  train      3       71170       6.0             0
# 2021-03-25   25    127  train      3       71170       4.0             0
# 2021-03-26   26    128  train      3       71170       5.0             0
# 2021-03-27   27    129  train      3       71170       5.0             0
# 2021-03-28   28    130  train      3       71170       1.0             0
# 2021-04-09    9      2   test      4       71170       NaN             0
# 2021-04-10   10   6578   test      4       71170       NaN             0
# 2021-04-11   11  13154   test      4       71170       NaN             0
# 2021-04-12   12  19730   test      4       71170       NaN             0
# 2021-04-13   13  26306   test      4       71170       NaN             0
# 2021-04-14   14  32882   test      4       71170       NaN             0
# 2021-04-15   15  39458   test      4       71170       NaN             0
#
#             target  lag_period_1  lag_period_2  lag_period_3  lagf_mean  \
# date
# 2021-02-09     1.0           NaN           NaN           NaN        NaN
# 2021-02-10     3.0           NaN           NaN           NaN        NaN
# 2021-02-11     3.0           NaN           NaN           NaN        NaN
# 2021-02-12     3.0           NaN           NaN           NaN        NaN
# 2021-02-14     2.0           NaN           NaN           NaN        NaN
# 2021-02-15     1.0           NaN           NaN           NaN        NaN
# 2021-02-16     3.0           NaN           NaN           NaN        NaN
# 2021-02-17     2.0           NaN           NaN           NaN        NaN
# 2021-02-18     4.0           NaN           NaN           NaN        NaN
# 2021-02-20     2.0           NaN           NaN           NaN        NaN
# 2021-02-23     1.0           NaN           NaN           NaN        NaN
# 2021-02-26     1.0           NaN           NaN           NaN        NaN
# 2021-02-27     2.0           NaN           NaN           NaN        NaN
# 2021-02-28     3.0           NaN           NaN           NaN        NaN
# 2021-03-01     2.0           NaN           NaN           NaN        NaN
# 2021-03-02     1.0           NaN           NaN           NaN        NaN
# 2021-03-03     2.0           NaN           NaN           NaN        NaN
# 2021-03-04     3.0           NaN           NaN           NaN        NaN
# 2021-03-06     7.0           NaN           NaN           NaN        NaN
# 2021-03-07     4.0           NaN           NaN           NaN        NaN
# 2021-03-08     3.0           NaN           NaN           NaN        NaN
# 2021-03-23     3.0           NaN           NaN           NaN        NaN
# 2021-03-24     6.0           NaN           NaN           NaN        NaN
# 2021-03-25     4.0           NaN           NaN           NaN        NaN
# 2021-03-26     5.0           1.0           NaN           NaN        1.0
# 2021-03-27     5.0           3.0           NaN           NaN        3.0
# 2021-03-28     1.0           3.0           NaN           NaN        3.0
# 2021-04-09     NaN           3.0           NaN           NaN        3.0
# 2021-04-10     NaN           2.0           NaN           NaN        2.0
# 2021-04-11     NaN           1.0           NaN           NaN        1.0
# 2021-04-12     NaN           3.0           NaN           NaN        3.0
# 2021-04-13     NaN           2.0           NaN           NaN        2.0
# 2021-04-14     NaN           4.0           NaN           NaN        4.0
# 2021-04-15     NaN           2.0           NaN           NaN        2.0
#
#             lagf_std
# date
# 2021-02-09       NaN
# 2021-02-10       NaN
# 2021-02-11       NaN
# 2021-02-12       NaN
# 2021-02-14       NaN
# 2021-02-15       NaN
# 2021-02-16       NaN
# 2021-02-17       NaN
# 2021-02-18       NaN
# 2021-02-20       NaN
# 2021-02-23       NaN
# 2021-02-26       NaN
# 2021-02-27       NaN
# 2021-02-28       NaN
# 2021-03-01       NaN
# 2021-03-02       NaN
# 2021-03-03       NaN
# 2021-03-04       NaN
# 2021-03-06       NaN
# 2021-03-07       NaN
# 2021-03-08       NaN
# 2021-03-23       NaN
# 2021-03-24       NaN
# 2021-03-25       NaN
# 2021-03-26       NaN
# 2021-03-27       NaN
# 2021-03-28       NaN
# 2021-04-09       NaN
# 2021-04-10       NaN
# 2021-04-11       NaN
# 2021-04-12       NaN
# 2021-04-13       NaN
# 2021-04-14       NaN
# 2021-04-15       NaN

# %%
for i in tqdm(range(len(df_test))):
    tek_prod_id=df_test.iloc[i,:]['product_id']
    tek_store_id=df_test.iloc[i,:]['warehouse_id']
    tek_day=df_test.iloc[i,:]['day']
    
    tek_df=df_train[df_train['product_id']==tek_prod_id]
    tek_df=tek_df[tek_df['warehouse_id']==tek_store_id]
    
    tek_df1=tek_df[tek_df['day']==tek_day]
    if(len(tek_df1)>0):
        df_test.iloc[i,5]=np.round(tek_df1['quantity'].mean())
    else:
        tek_df2=df_train[df_train['day'].isin([tek_day-1,tek_day+1]) ]
        if (len(tek_df2)>0):
            df_test.iloc[i,5]=np.round(tek_df2['quantity'].mean())
        else:
            df_test.iloc[i,5]=0.0

# %%
set1=set(df_train['product_id'])
set2=set(df_test['product_id'])
print(len(set1))
print(len(set1.intersection(set2)))
# Out:
# 3288
# 3288

# %%
len(set1)
# Out:
# 3288

# %%
len(set1.intersection(set2))
# Out:
# 3288
